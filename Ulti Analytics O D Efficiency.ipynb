# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ulti_df = pd.read_csv('WY-Wolves/1617SUISWolves-stats.csv')
ulti_df.head()
# Out:
#           Date/Time  Tournamemnt     Opponent  Point Elapsed Seconds Line  \
# 0  2016-10-28 16:12  Fall League  YewWah Dogs                    171    O
# 1  2016-10-28 16:12  Fall League  YewWah Dogs                    171    O
# 2  2016-10-28 16:12  Fall League  YewWah Dogs                    171    O
# 3  2016-10-28 16:12  Fall League  YewWah Dogs                    171    O
# 4  2016-10-28 16:12  Fall League  YewWah Dogs                    171    O
#
#    Our Score - End of Point  Their Score - End of Point Event Type Action  \
# 0                         1                           0    Offense  Catch
# 1                         1                           0    Offense  Catch
# 2                         1                           0    Offense  Catch
# 3                         1                           0    Offense  Catch
# 4                         1                           0    Offense  Catch
#
#              Passer           ...            Begin Area Begin X  Begin Y  \
# 0  #22 Paul Simpson           ...                   NaN     NaN      NaN
# 1    #14 Cecilia Wu           ...                   NaN     NaN      NaN
# 2  #22 Paul Simpson           ...                   NaN     NaN      NaN
# 3    #14 Cecilia Wu           ...                   NaN     NaN      NaN
# 4  #22 Paul Simpson           ...                   NaN     NaN      NaN
#
#   End Area End X End Y Distance Unit of Measure Absolute Distance  \
# 0      NaN   NaN   NaN                      NaN               NaN
# 1      NaN   NaN   NaN                      NaN               NaN
# 2      NaN   NaN   NaN                      NaN               NaN
# 3      NaN   NaN   NaN                      NaN               NaN
# 4      NaN   NaN   NaN                      NaN               NaN
#
#   Lateral Distance Toward Our Goal Distance
# 0              NaN                      NaN
# 1              NaN                      NaN
# 2              NaN                      NaN
# 3              NaN                      NaN
# 4              NaN                      NaN
#
# [5 rows x 52 columns]

# %%
player = '#77 Zoe Wu'
o_scored = len(ulti_df[(ulti_df['Line'] == 'O') & (ulti_df['Action'] == 'Goal') & (ulti_df['Event Type'] == 'Offense') &
            ((ulti_df['Player 0'] == player) |
             (ulti_df['Player 1'] == player) |
             (ulti_df['Player 2'] == player) |
             (ulti_df['Player 3'] == player) |
             (ulti_df['Player 4'] == player) |
             (ulti_df['Player 5'] == player) |
             (ulti_df['Player 6'] == player))])
o_lost = len(ulti_df[(ulti_df['Line'] == 'O') & (ulti_df['Action'] == 'Goal') & (ulti_df['Event Type'] == 'Defense') &
            ((ulti_df['Player 0'] == player) |
             (ulti_df['Player 1'] == player) |
             (ulti_df['Player 2'] == player) |
             (ulti_df['Player 3'] == player) |
             (ulti_df['Player 4'] == player) |
             (ulti_df['Player 5'] == player) |
             (ulti_df['Player 6'] == player))])
(o_scored - o_lost)/(o_scored + o_lost)
# Out:
# 0.1
